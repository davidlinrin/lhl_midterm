# %% [markdown]
# ### Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics
from sklearn import preprocessing
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import f_regression, SelectKBest
from sklearn.cluster import DBSCAN
from sklearn.cluster import KMeans
from sklearn.linear_model import LinearRegression
import plotly.express as px

import copy
import seaborn as sns
import os
from scipy import stats
import datetime

import sqlite3 as sqlite
from sqlalchemy import create_engine
# %matplotlib inline

# %%
data_path = '/mnt/d/lighthouse/Midterm_data/'

# %%
# 15927485 rows × 42
flights = pd.read_csv(data_path + 'flights.csv', header = 0, low_memory=False)
#flights_test =pd.read_csv(data_path + 'flights_test.csv', header = 0)

# %%
# making duplicate so we dont have to re-read large csv files
flights_clean = copy.deepcopy(flights)

# %% [markdown]
# ## Nan

# %%
total = flights_clean.isnull().sum().sort_values(ascending = False)
percent = (flights_clean.isnull().sum()/flights_clean.isnull().count()).sort_values(ascending = False)
missing_data = pd.concat([total,percent], axis=1, keys=['Total', 'Percent'])

# %%
#missing_data.head(15)

# %%
# dropping columsn with 80% missing AND [origin_city_name, dest_city_name] since we have [orgin, dest]
# dropping [cancelled, diverted, flights, dup] since they only contain one value
cols_to_drop_nan = list(missing_data[missing_data['Percent'] > 0.8].index)
cols_to_drop_other = ['dep_delay','taxi_out','taxi_in', 'wheels_off', 'wheels_on', 'arr_time', 'cancelled', 'diverted','actual_elapsed_time','air_time', 'flights', 'dup', 'dep_time']
flights_clean.drop(cols_to_drop_nan, axis = 1, inplace = True)
flights_clean.drop(cols_to_drop_other, axis = 1, inplace = True)
#flights_test.drop(['dup','flights'], axis =1, inplace=True)

# %% [markdown]
# ## rows with Nan

# %%
# before: (15927485, 20)
# after: 15652397 rows × 20 columns
# lost 3% of data, no biggie
flights_clean.dropna(inplace = True)

# before: (660556, 18)
# after: (659057, 18)
#flights_test.dropna(inplace = True)

# %%
# (15605076, 19)
flights_clean.shape
# Out:
# (15615740, 19)

# %% [markdown]
# ### seperate numerical/categorical

# %%
# 9 numerical features
numerical = list(flights_clean.dtypes[flights_clean.dtypes != 'object'].index)
# 10 categorical features 
categorical = list(flights_clean.dtypes[flights_clean.dtypes == 'object'].index)

# 8 categorical features 
#numerical_test = list(flights_test.dtypes[flights_test.dtypes != 'object'].index)
# 10 categorical features 
#categorical_test = list(flights_test.dtypes[flights_test.dtypes == 'object'].index)

# %%
flights_numerical = copy.deepcopy(flights_clean[numerical])
flights_categorical = copy.deepcopy(flights_clean[categorical])

#test_numerical = copy.deepcopy(flights_test[numerical_test])
#test_categorical = copy.deepcopy(flights_test[categorical_test])

# %% [markdown]
# # Binning and dropping correlated columns

# %% [markdown]
# ### seperate year-month-day (stopped doing for test set at this point)

# %%
flights_categorical['fl_date'] = pd.to_datetime(flights_categorical['fl_date'])
flights_categorical['year'] = flights_categorical['fl_date'].dt.year
flights_categorical['month'] = flights_categorical['fl_date'].dt.month
flights_categorical['date'] = flights_categorical['fl_date'].dt.day
# Dropping the old date column
flights_categorical.drop('fl_date', axis = 1, inplace = True)

# %% [markdown]
# ### Dropping origin_city_name and dest_city_name

# %%
# dropping since origin and dest tells us the city
flights_categorical.drop(['origin_city_name', 'dest_city_name'],axis =1,inplace = True)

# %%
flights_categorical.shape
# Out:
# (15615740, 7)

# %%
flights_categorical.drop(['branded_code_share','mkt_carrier','op_unique_carrier'], axis = 1, inplace = True)

# %%
flights_categorical
# Out:
#          mkt_unique_carrier tail_num origin dest  year  month  date
# 0                        WN   N8540V    MCI  PHX  2019      3    25
# 1                        WN   N8656B    MCI  PHX  2019      3    25
# 2                        WN   N8583Z    MCI  PHX  2019      3    25
# 3                        WN   N737JW    MCI  RDU  2019      3    25
# 4                        WN   N705SW    MCI  RSW  2019      3    25
# ...                     ...      ...    ...  ...   ...    ...   ...
# 15927480                 WN   N7702A    MCI  MSY  2019      3    25
# 15927481                 WN   N7878A    MCI  OAK  2019      3    25
# 15927482                 WN   N760SW    MCI  PDX  2019      3    25
# 15927483                 WN   N8542Z    MCI  PHX  2019      3    25
# 15927484                 WN   N783SW    MCI  PHX  2019      3    25
#
# [15615740 rows x 7 columns]

# %% [markdown]
# ### encode all string variables

# %%
# converting category to numbers
flights_categorical['mkt_unique_carrier'] = pd.factorize(flights_categorical['mkt_unique_carrier'])[0]
flights_categorical['tail_num'] = pd.factorize(flights_categorical['tail_num'])[0]
flights_categorical['origin'] = pd.factorize(flights_categorical['origin'])[0]
flights_categorical['dest'] = pd.factorize(flights_categorical['dest'])[0]

# %%
flights_categorical
# Out:
#           mkt_unique_carrier  tail_num  origin  dest  year  month  date
# 0                          0         0       0     0  2019      3    25
# 1                          0         1       0     0  2019      3    25
# 2                          0         2       0     0  2019      3    25
# 3                          0         3       0     1  2019      3    25
# 4                          0         4       0     2  2019      3    25
# ...                      ...       ...     ...   ...   ...    ...   ...
# 15927480                   0       143       0    30  2019      3    25
# 15927481                   0       197       0    31  2019      3    25
# 15927482                   0       290       0    58  2019      3    25
# 15927483                   0       293       0     0  2019      3    25
# 15927484                   0       500       0     0  2019      3    25
#
# [15615740 rows x 7 columns]

# %% [markdown]
# ### Standardize/scale numerical

# %%
flights_numerical

# %%
flights_numerical.drop(['crs_elapsed_time','op_carrier_fl_num'], axis = 1, inplace= True)

# %%
numerical_var = flights_numerical[['crs_dep_time','crs_arr_time','arr_delay','distance']].values
num_scaled = StandardScaler().fit_transform(numerical_var)
num_scaled
# Out:
# array([[ 0.87097422,  0.70950578, -0.35040153,  0.46598272],
#        [ 1.37134788,  1.10635953, -0.49075525,  0.46598272],
#        [-1.61047067, -1.64257867, -0.31030047,  0.46598272],
#        ...,
#        [-0.83438091, -0.72303948, -0.47070472,  1.21186979],
#        [-0.41570091, -0.51977293, -0.330351  ,  0.46598272],
#        [ 0.04382592, -0.07452237, -0.330351  ,  0.46598272]])

# %%
flights_numerical['crs_dep_time'] = num_scaled[:,0]
flights_numerical['crs_arr_time'] = num_scaled[:,1]
flights_numerical['arr_delay'] = num_scaled[:,2]
flights_numerical['distance'] = num_scaled[:,3]

# %%
flights_categorical
# Out:
#           mkt_unique_carrier  tail_num  origin  dest  year  month  date
# 0                          0         0       0     0  2019      3    25
# 1                          0         1       0     0  2019      3    25
# 2                          0         2       0     0  2019      3    25
# 3                          0         3       0     1  2019      3    25
# 4                          0         4       0     2  2019      3    25
# ...                      ...       ...     ...   ...   ...    ...   ...
# 15927480                   0       143       0    30  2019      3    25
# 15927481                   0       197       0    31  2019      3    25
# 15927482                   0       290       0    58  2019      3    25
# 15927483                   0       293       0     0  2019      3    25
# 15927484                   0       500       0     0  2019      3    25
#
# [15615740 rows x 7 columns]

# %%
flights_numerical
# Out:
#           mkt_carrier_fl_num  origin_airport_id  dest_airport_id  \
# 0                       2098              13198            14107
# 1                       2238              13198            14107
# 2                       2451              13198            14107
# 3                       2213              13198            14492
# 4                       2096              13198            14635
# ...                      ...                ...              ...
# 15927480                2189              13198            13495
# 15927481                1291              13198            13796
# 15927482                2470              13198            14057
# 15927483                1651              13198            14107
# 15927484                1962              13198            14107
#
#           crs_dep_time  crs_arr_time  arr_delay  distance
# 0             0.870974      0.709506  -0.350402  0.465983
# 1             1.371348      1.106360  -0.490755  0.465983
# 2            -1.610471     -1.642579  -0.310300  0.465983
# 3             0.452294      0.815979   1.774955  0.227571
# 4            -0.579088     -0.103560   2.937886  0.655009
# ...                ...           ...        ...       ...
# 15927480      1.483677      1.474175  -0.169947 -0.138560
# 15927481     -0.262525     -0.248751   1.875208  1.223790
# 15927482     -0.834381     -0.723039  -0.470705  1.211870
# 15927483     -0.415701     -0.519773  -0.330351  0.465983
# 15927484      0.043826     -0.074522  -0.330351  0.465983
#
# [15615740 rows x 7 columns]

# %% [markdown]
# ### merging into into model data

# %%
flights_final = pd.concat([flights_numerical, flights_categorical], axis=1)
flights_final.reset_index(drop=True)
flights_final
# Out:
#           mkt_carrier_fl_num  origin_airport_id  dest_airport_id  \
# 0                       2098              13198            14107
# 1                       2238              13198            14107
# 2                       2451              13198            14107
# 3                       2213              13198            14492
# 4                       2096              13198            14635
# ...                      ...                ...              ...
# 15927480                2189              13198            13495
# 15927481                1291              13198            13796
# 15927482                2470              13198            14057
# 15927483                1651              13198            14107
# 15927484                1962              13198            14107
#
#           crs_dep_time  crs_arr_time  arr_delay  distance  mkt_unique_carrier  \
# 0             0.870974      0.709506  -0.350402  0.465983                   0
# 1             1.371348      1.106360  -0.490755  0.465983                   0
# 2            -1.610471     -1.642579  -0.310300  0.465983                   0
# 3             0.452294      0.815979   1.774955  0.227571                   0
# 4            -0.579088     -0.103560   2.937886  0.655009                   0
# ...                ...           ...        ...       ...                 ...
# 15927480      1.483677      1.474175  -0.169947 -0.138560                   0
# 15927481     -0.262525     -0.248751   1.875208  1.223790                   0
# 15927482     -0.834381     -0.723039  -0.470705  1.211870                   0
# 15927483     -0.415701     -0.519773  -0.330351  0.465983                   0
# 15927484      0.043826     -0.074522  -0.330351  0.465983                   0
#
#           tail_num  origin  dest  year  month  date
# 0                0       0     0  2019      3    25
# 1                1       0     0  2019      3    25
# 2                2       0     0  2019      3    25
# 3                3       0     1  2019      3    25
# 4                4       0     2  2019      3    25
# ...            ...     ...   ...   ...    ...   ...
# 15927480       143       0    30  2019      3    25
# 15927481       197       0    31  2019      3    25
# 15927482       290       0    58  2019      3    25
# 15927483       293       0     0  2019      3    25
# 15927484       500       0     0  2019      3    25
#
# [15615740 rows x 14 columns]

# %% [markdown]
# ### Correlation

# %%
df_corr = flights_final.corr().abs()
indices = np.where(df_corr > 0.8) 
indices = [(df_corr.index[x], df_corr.columns[y]) for x, y in zip(*indices) if x != y and x < y]
indices
# Out:
# []

# %%
fig, ax = plt.subplots(figsize=(10,10))
corrMatrix = flights_final.corr().abs()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
# no highly correlated features
for idx in indices: 
    try:
        flights_final.drop(idx[1], axis = 1, inplace=True)
    except KeyError:
        pass

# %%
flights_final.shape
# Out:
# (15615740, 14)

# %%
flights_final.to_csv('/mnt/d/lighthouse/Midterm_data/model_3_scaled.csv')

# %% [markdown]
# # Model

# %%
#flights_final = pd.read_csv(data_path + 'model_2_bin.csv', header = 0)
#flights_final.drop('Unnamed: 0', axis = 1, inplace= True)

# %%
flights_final
# Out:
#           mkt_carrier_fl_num  origin_airport_id  dest_airport_id  \
# 0                       2098              13198            14107
# 1                       2238              13198            14107
# 2                       2451              13198            14107
# 3                       2213              13198            14492
# 4                       2096              13198            14635
# ...                      ...                ...              ...
# 15927480                2189              13198            13495
# 15927481                1291              13198            13796
# 15927482                2470              13198            14057
# 15927483                1651              13198            14107
# 15927484                1962              13198            14107
#
#           crs_dep_time  crs_arr_time  arr_delay  distance  mkt_unique_carrier  \
# 0             0.870974      0.709506  -0.350402  0.465983                   0
# 1             1.371348      1.106360  -0.490755  0.465983                   0
# 2            -1.610471     -1.642579  -0.310300  0.465983                   0
# 3             0.452294      0.815979   1.774955  0.227571                   0
# 4            -0.579088     -0.103560   2.937886  0.655009                   0
# ...                ...           ...        ...       ...                 ...
# 15927480      1.483677      1.474175  -0.169947 -0.138560                   0
# 15927481     -0.262525     -0.248751   1.875208  1.223790                   0
# 15927482     -0.834381     -0.723039  -0.470705  1.211870                   0
# 15927483     -0.415701     -0.519773  -0.330351  0.465983                   0
# 15927484      0.043826     -0.074522  -0.330351  0.465983                   0
#
#           tail_num  origin  dest  year  month  date
# 0                0       0     0  2019      3    25
# 1                1       0     0  2019      3    25
# 2                2       0     0  2019      3    25
# 3                3       0     1  2019      3    25
# 4                4       0     2  2019      3    25
# ...            ...     ...   ...   ...    ...   ...
# 15927480       143       0    30  2019      3    25
# 15927481       197       0    31  2019      3    25
# 15927482       290       0    58  2019      3    25
# 15927483       293       0     0  2019      3    25
# 15927484       500       0     0  2019      3    25
#
# [15615740 rows x 14 columns]

# %%
set(flights_final.columns) ^ set(flights_test.columns)
# Out:
# {'arr_delay',
#  'bin_branded_code_share',
#  'bin_mkt_unique_carrier',
#  'bin_op_unique_carrier',
#  'branded_code_share',
#  'dest_city_name',
#  'distance',
#  'mkt_carrier',
#  'mkt_unique_carrier',
#  'op_carrier_fl_num',
#  'op_unique_carrier',
#  'origin_city_name'}

# %%
X = flights_final.drop('arr_delay', axis = 1)
y = flights_final['arr_delay']

# %%
X.shape
# Out:
# (15615740, 13)

# %%
y.shape
# Out:
# (15615740,)

# %% [markdown]
# ### sklearn

# %%
reg = LinearRegression().fit(X, y)

# %%
reg.score(X, y)
# Out:
# 0.010735862184143241

# %%
reg.coef_
# Out:
# array([ 1.49232291e-05, -1.52487378e-06, -4.64327727e-07,  6.65462783e-02,
#         3.57724944e-02, -8.74279317e-03,  1.62109115e-02,  1.27620814e-06,
#         7.78145182e-05, -7.74114547e-05,  8.52231390e-03, -1.89424315e-03,
#        -3.73363398e-04])

# %% [markdown]
# ### Statsmodel

# %%
res = sm.OLS(y, X).fit()

# %%
print(res.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              arr_delay   R-squared (uncentered):                   0.011
# Model:                            OLS   Adj. R-squared (uncentered):              0.011
# Method:                 Least Squares   F-statistic:                          1.301e+04
# Date:                Wed, 26 Aug 2020   Prob (F-statistic):                        0.00
# Time:                        17:38:53   Log-Likelihood:                     -2.2074e+07
# No. Observations:            15615740   AIC:                                  4.415e+07
# Df Residuals:                15615727   BIC:                                  4.415e+07
# Df Model:                          13
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# mkt_carrier_fl_num  1.489e-05    1.5e-07     99.367      0.000    1.46e-05    1.52e-05
# origin_airport_id  -1.525e-06   1.79e-07     -8.533      0.000   -1.88e-06   -1.17e-06
# dest_airport_id    -4.751e-07   1.66e-07     -2.854      0.004   -8.01e-07   -1.49e-07
# crs_dep_time           0.0665      0.000    188.526      0.000       0.066       0.067
# crs_arr_time           0.0358      0.000    101.368      0.000       0.035       0.036
# distance              -0.0087      0.000    -31.991      0.000      -0.009      -0.008
# mkt_unique_carrier     0.0162      0.000    118.817      0.000       0.016       0.016
# tail_num             1.21e-06   1.55e-07      7.800      0.000    9.06e-07    1.51e-06
# origin              7.826e-05   4.07e-06     19.249      0.000    7.03e-05    8.62e-05
# dest               -7.663e-05    4.1e-06    -18.668      0.000   -8.47e-05   -6.86e-05
# year               -1.967e-05   1.64e-06    -11.968      0.000   -2.29e-05   -1.65e-05
# month                 -0.0019   7.41e-05    -25.547      0.000      -0.002      -0.002
# date                  -0.0004   2.87e-05    -13.091      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                 22801557.367   Durbin-Watson:                   1.720
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      14343036864.922
# Skew:                           8.704   Prob(JB):                         0.00
# Kurtosis:                     150.448   Cond. No.                     3.39e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.39e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
